# %%
#pip install -U dataprep
# https://my.visualstudio.com/Downloads?q=visual%20studio%202019&wt.mc_id=o~msft~vscom~older-downloads
# Out:
# Collecting dataprep
#   Downloading dataprep-0.4.3-py3-none-any.whl (9.5 MB)
#      ---------------------------------------- 9.5/9.5 MB 6.6 MB/s eta 0:00:00
# Collecting aiohttp<4.0,>=3.6 (from dataprep)
#   Downloading aiohttp-3.8.4-cp37-cp37m-win_amd64.whl (322 kB)
#      ------------------------------------- 322.2/322.2 kB 10.1 MB/s eta 0:00:00
# Collecting bokeh<3,>=2 (from dataprep)
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#      ---------------------------------------- 18.5/18.5 MB 8.6 MB/s eta 0:00:00
# Collecting dask[array,dataframe,delayed]<2022.0,>=2021.11 (from dataprep)
#   Downloading dask-2021.12.0-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: flask<3,>=2 in c:\python 3.7.1\lib\site-packages (from dataprep) (2.2.3)
# Collecting flask_cors<4.0.0,>=3.0.10 (from dataprep)
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting ipywidgets<8.0,>=7.5 (from dataprep)
#   Downloading ipywidgets-7.7.5-py2.py3-none-any.whl (123 kB)
#      -------------------------------------- 123.9/123.9 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: jinja2<4,>=3 in c:\python 3.7.1\lib\site-packages (from dataprep) (3.1.2)
# Collecting jsonpath-ng<2.0,>=1.5 (from dataprep)
#   Downloading jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Collecting metaphone<0.7,>=0.6 (from dataprep)
#   Downloading Metaphone-0.6.tar.gz (14 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting nltk<4.0.0,>=3.6.7 (from dataprep)
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0,>=1.21 in c:\python 3.7.1\lib\site-packages (from dataprep) (1.21.6)
# Requirement already satisfied: pandas<2.0,>=1.1 in c:\python 3.7.1\lib\site-packages (from dataprep) (1.3.5)
# Collecting pydantic<2.0,>=1.6 (from dataprep)
#   Downloading pydantic-1.10.7-cp37-cp37m-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 14.8 MB/s eta 0:00:00
# Collecting pystache<0.7.0,>=0.6.0 (from dataprep)
#   Downloading pystache-0.6.0.tar.gz (78 kB)
#      ---------------------------------------- 78.2/78.2 kB 4.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting python-Levenshtein<0.13.0,>=0.12.2 (from dataprep)
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      ---------------------------------------- 50.5/50.5 kB 2.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting python-crfsuite<0.10.0,>=0.9.7 (from dataprep)
#   Downloading python_crfsuite-0.9.9-cp37-cp37m-win_amd64.whl (137 kB)
#      -------------------------------------- 137.5/137.5 kB 8.0 MB/s eta 0:00:00
# Collecting python-stdnum<2.0,>=1.16 (from dataprep)
#   Downloading python_stdnum-1.18-py2.py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 12.8 MB/s eta 0:00:00
# Collecting regex<2022.0.0,>=2021.8.3 (from dataprep)
#   Downloading regex-2021.11.10-cp37-cp37m-win_amd64.whl (272 kB)
#      ------------------------------------- 272.6/272.6 kB 16.4 MB/s eta 0:00:00
# Collecting scipy<=1.7.1 (from dataprep)
#   Downloading scipy-1.7.1-cp37-cp37m-win_amd64.whl (33.6 MB)
#      ---------------------------------------- 33.6/33.6 MB 9.1 MB/s eta 0:00:00
# Collecting sqlalchemy<2.0.0,>=1.4.32 (from dataprep)
#   Downloading SQLAlchemy-1.4.48-cp37-cp37m-win_amd64.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0,>=4.48 in c:\python 3.7.1\lib\site-packages (from dataprep) (4.65.0)
# Collecting varname<0.9.0,>=0.8.1 (from dataprep)
#   Downloading varname-0.8.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: wordcloud<2.0,>=1.8 in c:\python 3.7.1\lib\site-packages (from dataprep) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\python 3.7.1\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\python 3.7.1\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (3.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0,>=3.6->dataprep)
#   Downloading multidict-6.0.4-cp37-cp37m-win_amd64.whl (27 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp<4.0,>=3.6->dataprep)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0,>=3.6->dataprep)
#   Downloading yarl-1.9.2-cp37-cp37m-win_amd64.whl (61 kB)
#      ---------------------------------------- 61.4/61.4 kB 1.1 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0,>=3.6->dataprep)
#   Downloading frozenlist-1.3.3-cp37-cp37m-win_amd64.whl (34 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0,>=3.6->dataprep)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting asynctest==0.13.0 (from aiohttp<4.0,>=3.6->dataprep)
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\python 3.7.1\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (4.3.0)
# Requirement already satisfied: packaging>=16.8 in c:\users\sejin\appdata\roaming\python\python37\site-packages (from bokeh<3,>=2->dataprep) (23.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\python 3.7.1\lib\site-packages (from bokeh<3,>=2->dataprep) (9.2.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\python 3.7.1\lib\site-packages (from bokeh<3,>=2->dataprep) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\sejin\appdata\roaming\python\python37\site-packages (from bokeh<3,>=2->dataprep) (6.2)
# Collecting cloudpickle>=1.1.1 (from dask[array,dataframe,delayed]<2022.0,>=2021.11->dataprep)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting fsspec>=0.6.0 (from dask[array,dataframe,delayed]<2022.0,>=2021.11->dataprep)
#   Downloading fsspec-2023.1.0-py3-none-any.whl (143 kB)
#      -------------------------------------- 143.0/143.0 kB 8.3 MB/s eta 0:00:00
# Collecting partd>=0.3.10 (from dask[array,dataframe,delayed]<2022.0,>=2021.11->dataprep)
#   Downloading partd-1.4.0-py3-none-any.whl (18 kB)
# Collecting toolz>=0.8.2 (from dask[array,dataframe,delayed]<2022.0,>=2021.11->dataprep)
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ---------------------------------------- 55.8/55.8 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\python 3.7.1\lib\site-packages (from flask<3,>=2->dataprep) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\python 3.7.1\lib\site-packages (from flask<3,>=2->dataprep) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\python 3.7.1\lib\site-packages (from flask<3,>=2->dataprep) (8.1.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\python 3.7.1\lib\site-packages (from flask<3,>=2->dataprep) (6.3.0)
# Requirement already satisfied: Six in c:\python 3.7.1\lib\site-packages (from flask_cors<4.0.0,>=3.0.10->dataprep) (1.16.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\python 3.7.1\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (6.16.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\python 3.7.1\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\sejin\appdata\roaming\python\python37\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.9.0)
# Collecting widgetsnbextension~=3.6.4 (from ipywidgets<8.0,>=7.5->dataprep)
#   Downloading widgetsnbextension-3.6.4-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=4.0.0 in c:\python 3.7.1\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (7.34.0)
# Collecting jupyterlab-widgets<3,>=1.0.0 (from ipywidgets<8.0,>=7.5->dataprep)
#   Downloading jupyterlab_widgets-1.1.4-py3-none-any.whl (246 kB)
#      ------------------------------------- 246.1/246.1 kB 14.7 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python 3.7.1\lib\site-packages (from jinja2<4,>=3->dataprep) (2.1.2)
# Collecting ply (from jsonpath-ng<2.0,>=1.5->dataprep)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ---------------------------------------- 49.6/49.6 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: decorator in c:\python 3.7.1\lib\site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (5.1.1)
# Requirement already satisfied: joblib in c:\python 3.7.1\lib\site-packages (from nltk<4.0.0,>=3.6.7->dataprep) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\python 3.7.1\lib\site-packages (from pandas<2.0,>=1.1->dataprep) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\python 3.7.1\lib\site-packages (from pandas<2.0,>=1.1->dataprep) (2023.3)
# Requirement already satisfied: setuptools in c:\python 3.7.1\lib\site-packages (from python-Levenshtein<0.13.0,>=0.12.2->dataprep) (39.0.1)
# Collecting greenlet!=0.4.17 (from sqlalchemy<2.0.0,>=1.4.32->dataprep)
#   Downloading greenlet-2.0.2-cp37-cp37m-win_amd64.whl (192 kB)
#      ------------------------------------- 192.4/192.4 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\python 3.7.1\lib\site-packages (from tqdm<5.0,>=4.48->dataprep) (0.4.6)
# Collecting asttokens<3.0.0,>=2.0.0 (from varname<0.9.0,>=0.8.1->dataprep)
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Collecting executing<0.9.0,>=0.8.3 (from varname<0.9.0,>=0.8.1->dataprep)
#   Downloading executing-0.8.3-py2.py3-none-any.whl (16 kB)
# Collecting pure_eval<1.0.0 (from varname<0.9.0,>=0.8.1->dataprep)
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: matplotlib in c:\python 3.7.1\lib\site-packages (from wordcloud<2.0,>=1.8->dataprep) (3.5.3)
# Requirement already satisfied: zipp>=0.5 in c:\python 3.7.1\lib\site-packages (from importlib-metadata>=3.6.0->flask<3,>=2->dataprep) (3.15.0)
# Requirement already satisfied: debugpy>=1.0 in c:\python 3.7.1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.6.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\python 3.7.1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\python 3.7.1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\python 3.7.1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.5.6)
# Requirement already satisfied: psutil in c:\python 3.7.1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (5.9.4)
# Requirement already satisfied: pyzmq>=17 in c:\python 3.7.1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (25.0.2)
# Requirement already satisfied: jedi>=0.16 in c:\python 3.7.1\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.2)
# Requirement already satisfied: pickleshare in c:\python 3.7.1\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\python 3.7.1\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (3.0.38)
# Requirement already satisfied: pygments in c:\python 3.7.1\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (2.14.0)
# Requirement already satisfied: backcall in c:\python 3.7.1\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Collecting locket (from partd>=0.3.10->dask[array,dataframe,delayed]<2022.0,>=2021.11->dataprep)
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: notebook>=4.4.1 in c:\python 3.7.1\lib\site-packages (from widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (6.5.4)
# Requirement already satisfied: idna>=2.0 in c:\python 3.7.1\lib\site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->dataprep) (3.4)
# Requirement already satisfied: cycler>=0.10 in c:\python 3.7.1\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python 3.7.1\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (4.36.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python 3.7.1\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python 3.7.1\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (3.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\python 3.7.1\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.3)
# Requirement already satisfied: entrypoints in c:\python 3.7.1\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\python 3.7.1\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (4.12.0)
# Requirement already satisfied: argon2-cffi in c:\python 3.7.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (21.3.0)
# Requirement already satisfied: nbformat in c:\python 3.7.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (5.8.0)
# Requirement already satisfied: nbconvert>=5 in c:\python 3.7.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (7.4.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\python 3.7.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\python 3.7.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\python 3.7.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.16.0)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\python 3.7.1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.0.0)
# Requirement already satisfied: wcwidth in c:\python 3.7.1\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.6)
# Requirement already satisfied: pywin32>=1.0 in c:\python 3.7.1\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (306)
# Requirement already satisfied: jupyter-server>=1.8 in c:\python 3.7.1\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in c:\python 3.7.1\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.2.3)
# Requirement already satisfied: beautifulsoup4 in c:\python 3.7.1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (4.12.1)
# Requirement already satisfied: bleach in c:\python 3.7.1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (6.0.0)
# Requirement already satisfied: defusedxml in c:\python 3.7.1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\python 3.7.1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in c:\python 3.7.1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in c:\python 3.7.1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\python 3.7.1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\python 3.7.1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\python 3.7.1\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\python 3.7.1\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\python 3.7.1\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\python 3.7.1\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (21.2.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\python 3.7.1\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (5.12.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\python 3.7.1\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\python 3.7.1\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.19.3)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\python 3.7.1\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (3.6.2)
# Requirement already satisfied: websocket-client in c:\python 3.7.1\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\python 3.7.1\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\python 3.7.1\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (2.4)
# Requirement already satisfied: webencodings in c:\python 3.7.1\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\python 3.7.1\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (1.3.0)
# Requirement already satisfied: pycparser in c:\python 3.7.1\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0,>=7.5->dataprep) (2.21)
# Building wheels for collected packages: metaphone, pystache, python-Levenshtein
#   Building wheel for metaphone (pyproject.toml): started
#   Building wheel for metaphone (pyproject.toml): finished with status 'done'
#   Created wheel for metaphone: filename=UNKNOWN-0.0.0-py3-none-any.whl size=939 sha256=9c08e9013bbe1d97540d95f51a2820d2ce398f60267309a73e476e5eeae5d31a
#   Stored in directory: c:\users\sejin\appdata\local\pip\cache\wheels\1d\a8\cb\6f8902aa5457bd71344e00665c230e9c45255b3f57f2194a0f
#   Building wheel for pystache (pyproject.toml): started
#   Building wheel for pystache (pyproject.toml): finished with status 'done'
#   Created wheel for pystache: filename=UNKNOWN-0.0.0-py3-none-any.whl size=937 sha256=73959cf5da4e1c4a5f1cbb0083dbe51ba74e99ae613abb5839ef7b2c774eb07b
#   Stored in directory: c:\users\sejin\appdata\local\pip\cache\wheels\78\87\45\383bd15701a08a94c735e9eaf3ff3299655684aaca63bbad96
#   Building wheel for python-Levenshtein (pyproject.toml): started
#   Building wheel for python-Levenshtein (pyproject.toml): finished with status 'error'
# Failed to build metaphone pystache python-Levenshtein
#   WARNING: Built wheel for metaphone is invalid: Wheel has unexpected file name: expected 'metaphone', got 'UNKNOWN'
#   WARNING: Built wheel for pystache is invalid: Wheel has unexpected file name: expected 'pystache', got 'UNKNOWN'
#   error: subprocess-exited-with-error
#
#   × Building wheel for python-Levenshtein (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [27 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-37
#       creating build\lib.win-amd64-cpython-37\Levenshtein
#       copying Levenshtein\StringMatcher.py -> build\lib.win-amd64-cpython-37\Levenshtein
#       copying Levenshtein\__init__.py -> build\lib.win-amd64-cpython-37\Levenshtein
#       running egg_info
#       writing python_Levenshtein.egg-info\PKG-INFO
#       writing dependency_links to python_Levenshtein.egg-info\dependency_links.txt
#       writing namespace_packages to python_Levenshtein.egg-info\namespace_packages.txt
#       writing requirements to python_Levenshtein.egg-info\requires.txt
#       writing top-level names to python_Levenshtein.egg-info\top_level.txt
#       reading manifest file 'python_Levenshtein.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no previously-included files matching '*pyc' found anywhere in distribution
#       warning: no previously-included files matching '*so' found anywhere in distribution
#       warning: no previously-included files matching '.project' found anywhere in distribution
#       warning: no previously-included files matching '.pydevproject' found anywhere in distribution
#       adding license file 'COPYING'
#       writing manifest file 'python_Levenshtein.egg-info\SOURCES.txt'
#       copying Levenshtein\_levenshtein.c -> build\lib.win-amd64-cpython-37\Levenshtein
#       copying Levenshtein\_levenshtein.h -> build\lib.win-amd64-cpython-37\Levenshtein
#       running build_ext
#       building 'Levenshtein._levenshtein' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for python-Levenshtein
# ERROR: Could not build wheels for metaphone, pystache, python-Levenshtein, which is required to install pyproject.toml-based projects

# %%
import warnings
warnings.filterwarnings("ignore")
from dataprep.eda import plot, plot_correlation, create_report, plot_missing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9876\3402754257.py in <module>
#       1 import warnings
#       2 warnings.filterwarnings("ignore")
# ----> 3 from dataprep.eda import plot, plot_correlation, create_report, plot_missing
#
# ModuleNotFoundError: No module named 'dataprep'

# %%
import pandas as pd
df = pd.read_csv('DS_Seoul_Subway_boarding.csv')
df.head(48)
